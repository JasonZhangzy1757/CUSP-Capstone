# %% [markdown]
# # US-Ignite Portland ETL Notebook

# %% [markdown]
# ## Portland Datasets
#
# Portland:
#
# Building FootPrints: http://gis-pdx.opendata.arcgis.com/datasets/building-footprints
# GeoJson: https://opendata.arcgis.com/datasets/1078959662ce49cca059fe2f8930c194_48.geojson
#
# Traffic Counts: http://gis-pdx.opendata.arcgis.com/datasets/traffic-volume-counts
# GeoJson: https://opendata.arcgis.com/datasets/6ba5258ffea34e878168ddc8cf34f7e3_250.geojson
#
# Buildings Elevations: http://gis-pdx.opendata.arcgis.com/datasets/935e774546cf4383a881a9c12c182e6e_184
# GeoJson: https://opendata.arcgis.com/datasets/935e774546cf4383a881a9c12c182e6e_184.geojson
#
# Residential Building Permits: http://gis-pdx.opendata.arcgis.com/datasets/797a38ddb60a471392ea9134448ad6c2_89
# GeoJson: https://opendata.arcgis.com/datasets/797a38ddb60a471392ea9134448ad6c2_89.geojson
#
# Busineess Districts: http://gis-pdx.opendata.arcgis.com/datasets/65c53b0f616a4a13b51e40c237c70050_11
# GeoJson: https://opendata.arcgis.com/datasets/935e774546cf4383a881a9c12c182e6e_184.geojson
#
# Recommended Bike Routes: http://gis-pdx.opendata.arcgis.com/datasets/recommended-bicycle-routes
# GeoJson: https://opendata.arcgis.com/datasets/fcd1f0403cbf484bb46233b44d96f220_183.geojson
#
# Transit stop peak arrival: http://gis-pdx.opendata.arcgis.com/datasets/transit-stop-peak-arrival?selectedAttribute=PMPeakArrivals
# GeoJson: https://opendata.arcgis.com/datasets/9dbb8fa9235d4ac796065787599ab4ca_251.geojson

# %%
#import libraries from Carto.
from cartoframes.auth import set_default_credentials, Credentials
from cartoframes.viz import Map, Layer
#from cartoframes.data import Dataset
#from cartoframes.viz.helpers import color_continuous_layer
import pandas as pd
import geopandas as gpd
import fiona

#set_default_credentials(
 #   base_url='https://usignite.carto.com/',
  #  api_key='nJor0dLGngHDZnlUwqK1Ow'
#)

# %%
#load .env with credentials
from dotenv import load_dotenv
load_dotenv()
import os
BASE_URL = os.getenv("https://usignite-admin.carto.com/")
API_KEY = os.getenv("81c922dc336bd82103d92a768816a4567c444909")
USERNAME = os.getenv("usignite-admin")

set_default_credentials(
   base_url='https://usignite.carto.com/',
    api_key='nJor0dLGngHDZnlUwqK1Ow'
)

#credentials = Credentials(USERNAME, API_KEY)

# %%
print(API_KEY)
# Out:
# None

# %% [markdown]
# ## Extract: Bring GeoJson into Notebook

# %%
#url="https://opendata.arcgis.com/datasets/9dbb8fa9235d4ac796065787599ab4ca_251.geojson"

# %%
#transit_stop_peak_arrival_gpdf = gpd.read_file(url)

# %% [markdown]
# # tranffic count

# %%
url2="https://opendata.arcgis.com/datasets/6ba5258ffea34e878168ddc8cf34f7e3_250.geojson"
transit_volumn_count_gpdf = gpd.read_file(url2)

# %% [markdown]
# # Residential Building Permits

# %%
#url3="https://opendata.arcgis.com/datasets/797a38ddb60a471392ea9134448ad6c2_89.geojson"
#residential_permits_gpdf = gpd.read_file(url3)

# %% [markdown]
# # Business Districts

# %%
url4="https://opendata.arcgis.com/datasets/935e774546cf4383a881a9c12c182e6e_184.geojson"
business_districts_gpdf = gpd.read_file(url4)

# %% [markdown]
# ## Transform
# Add here some code to do data transformation (remove outliers, null values, etc.). It's probably best to do this type of work on the geopandas dataframe

# %%
transit_stop_peak_arrival_gpdf.head()
# Out:
#    OBJECTID  StopID  AMPeakArrivals  PMPeakArrivals MeetsStandard  \
# 0         1    3080             8.0            12.0           Yes
# 1         2    3076             8.0            12.0           Yes
# 2         3    3082             8.0            12.0           Yes
# 3         4   13770             6.0            11.0           Yes
# 4         5    3854             3.0             3.0            No
#
#   InBufferArea                     geometry
# 0          Yes  POINT (-122.61690 45.46176)
# 1          Yes  POINT (-122.62043 45.46046)
# 2          Yes  POINT (-122.62595 45.46209)
# 3          Yes  POINT (-122.63717 45.46275)
# 4          Yes  POINT (-122.63932 45.46128)

# %%
len(transit_stop_peak_arrival_gpdf)
# Out:
# 3808

# %%
df_final=pd.read_csv("~/Downloads/Final_merged.csv")

# %%
df_final.head()
# Out:
#    Unnamed: 0      geo_id    pop  \
# 0         509  6073015502  208.0
# 1         509  6073015502  234.0
# 2         509  6073015502  291.0
# 3         509  6073015502  365.0
# 4         509  6073015502  411.0
#
#                                        centroid  year  \
# 0  POINT (-116.8304254797509 32.81131603277056)  2010
# 1  POINT (-116.8304254797509 32.81131603277056)  2011
# 2  POINT (-116.8304254797509 32.81131603277056)  2012
# 3  POINT (-116.8304254797509 32.81131603277056)  2013
# 4  POINT (-116.8304645225708 32.81130364624261)  2014
#
#                                             geometry    edut  collegemale  \
# 0  MULTIPOLYGON (((-116.8583888559341 32.81723278...  1651.0        130.0
# 1  MULTIPOLYGON (((-116.8583888559341 32.81723278...  1717.0        124.0
# 2  MULTIPOLYGON (((-116.8583888559341 32.81723278...  1790.0        124.0
# 3  MULTIPOLYGON (((-116.8583888559341 32.81723278...  1900.0        141.0
# 4  MULTIPOLYGON (((-116.8583888559341 32.81723278...  1865.0        143.0
#
#    collegefemale  households  income    gini  total_p  ratio_65  zipcode  \
# 0          107.0        83.0   864.0  0.4400     2748  0.108806    91901
# 1          114.0        95.0   896.0  0.4080     2748  0.108806    91901
# 2          107.0       113.0   904.0  0.3790     2748  0.108806    91901
# 3          148.0       136.0   903.0  0.3782     2748  0.108806    91901
# 4          135.0       154.0   883.0  0.3837     2748  0.108806    91901
#
#         geoid  NAICS2012   Empratio  estabratio
# 0  6073015502          0  39.686888    2.360078
# 1  6073015502          0  41.095890    2.383562
# 2  6073015502          0   0.293542    0.029354
# 3  6073015502          0   0.176125    0.017613
# 4  6073015502          0   0.234834    0.023483

# %%
transit_volumn_count_gpdf.head()
# Out:
#    OBJECTID        CountID  ChannelID                     LocationDesc Bound  \
# 0         1   15041501.VL1     515519       NE 148TH AVE S of 148TH PL     N
# 1         2   15041504.VL1     515520       NE 148TH AVE S of 148TH PL     S
# 2         3  191001100.VL1     522196  NE 148TH AVE S of SACRAMENTO ST     N
# 3         4  191001104.VL1     522193  NE 148TH AVE S of SACRAMENTO ST     S
# 4         5   18010305.VL2     519475      NE 14TH AVE S of FREMONT ST     N
#
#              StartDate StartDay StartTime              EndDate EndDay  ...  \
# 0  2015-04-27T00:00:00      MON  14:15:00  2015-04-29T00:00:00    WED  ...
# 1  2015-04-27T00:00:00      MON  14:30:00  2015-04-29T00:00:00    WED  ...
# 2  2019-10-01T00:00:00      TUE  09:30:00  2019-10-02T00:00:00    WED  ...
# 3  2019-10-01T00:00:00      TUE  09:30:00  2019-10-02T00:00:00    WED  ...
# 4  2018-01-03T00:00:00      WED  15:00:00  2018-01-05T00:00:00    FRI  ...
#
#   Conditions  Comment  Duration  IntervalLen DeviceRef  LocationID  \
# 0                           183           15              LEG17936
# 1                           182           15              LEG17936
# 2                           103           15              LEG17892
# 3                           103           15              LEG17892
# 4              @ 3343       188           15              LEG18030
#
#    LocationClass                        CountLocDesc CountType  \
# 0        NODELEG       NE 148TH AVE S of NE 148TH PL    VOLUME
# 1        NODELEG       NE 148TH AVE S of NE 148TH PL    VOLUME
# 2        NODELEG  NE 148TH AVE S of NE SACRAMENTO ST    VOLUME
# 3        NODELEG  NE 148TH AVE S of NE SACRAMENTO ST    VOLUME
# 4        NODELEG      NE 14TH AVE S of NE FREMONT ST    VOLUME
#
#                       geometry
# 0  POINT (-122.51020 45.54448)
# 1  POINT (-122.51020 45.54448)
# 2  POINT (-122.51025 45.53949)
# 3  POINT (-122.51025 45.53949)
# 4  POINT (-122.65143 45.54811)
#
# [5 rows x 33 columns]

# %%
transit_volumn_count_gpdf.StartDate.unique()
# Out:
# array(['2015-04-27T00:00:00', '2019-10-01T00:00:00',
#        '2018-01-03T00:00:00', '2019-04-18T00:00:00',
#        '2018-02-15T00:00:00', '2019-11-12T00:00:00',
#        '2019-05-08T00:00:00', '2015-10-21T00:00:00',
#        '2015-10-27T00:00:00', '2019-06-26T00:00:00',
#        '2016-06-01T00:00:00', '2019-12-09T00:00:00',
#        '2018-11-29T00:00:00', '2018-07-09T00:00:00',
#        '2018-12-03T00:00:00', '2019-04-30T00:00:00',
#        '2019-05-21T00:00:00', '2019-09-19T00:00:00',
#        '2017-10-03T00:00:00', '2018-04-12T00:00:00',
#        '2018-05-17T00:00:00', '2016-03-29T00:00:00',
#        '2015-09-16T00:00:00', '2015-08-04T00:00:00',
#        '2020-01-06T00:00:00', '2015-09-14T00:00:00',
#        '2015-08-05T00:00:00', '2016-03-16T00:00:00',
#        '2015-08-06T00:00:00', '2015-04-01T00:00:00',
#        '2015-04-14T00:00:00', '2015-04-18T00:00:00',
#        '2015-04-19T00:00:00', '2016-10-03T00:00:00',
#        '2019-05-13T00:00:00', '2019-09-25T00:00:00',
#        '2018-11-27T00:00:00', '2015-04-13T00:00:00',
#        '2018-03-13T00:00:00', '2016-04-12T00:00:00',
#        '2015-06-09T00:00:00', '2015-12-14T00:00:00',
#        '2015-11-05T00:00:00', '2019-05-06T00:00:00',
#        '2015-04-21T00:00:00', '2015-11-04T00:00:00',
#        '2015-11-02T00:00:00', '2017-08-03T00:00:00',
#        '2015-12-09T00:00:00', '2015-11-12T00:00:00',
#        '2017-06-13T00:00:00', '2019-01-23T00:00:00',
#        '2016-02-11T00:00:00', '2018-01-17T00:00:00',
#        '2016-01-11T00:00:00', '2016-03-01T00:00:00',
#        '2019-04-29T00:00:00', '2019-07-24T00:00:00',
#        '2015-10-26T00:00:00', '2016-01-26T00:00:00',
#        '2016-01-27T00:00:00', '2016-01-25T00:00:00',
#        '2016-07-12T00:00:00', '2019-11-19T00:00:00',
#        '2017-12-14T00:00:00', '2016-01-13T00:00:00',
#        '2019-09-16T00:00:00', '2015-05-06T00:00:00',
#        '2015-02-18T00:00:00', '2015-09-23T00:00:00',
#        '2019-04-25T00:00:00', '2015-02-19T00:00:00',
#        '2016-01-20T00:00:00', '2016-02-04T00:00:00',
#        '2015-11-30T00:00:00', '2015-11-10T00:00:00',
#        '2017-12-13T00:00:00', '2018-01-08T00:00:00',
#        '2018-02-08T00:00:00', '2018-02-06T00:00:00',
#        '2018-10-02T00:00:00', '2015-02-10T00:00:00',
#        '2018-10-04T00:00:00', '2017-02-28T00:00:00',
#        '2016-02-09T00:00:00', '2016-02-29T00:00:00',
#        '2017-04-11T00:00:00', '2017-04-25T00:00:00',
#        '2017-04-24T00:00:00', '2018-02-28T00:00:00',
#        '2017-01-31T00:00:00', '2018-07-31T00:00:00',
#        '2018-10-01T00:00:00', '2019-10-08T00:00:00',
#        '2018-08-22T00:00:00', '2018-06-12T00:00:00',
#        '2018-01-02T00:00:00', '2019-04-17T00:00:00',
#        '2019-02-19T00:00:00', '2015-04-28T00:00:00',
#        '2016-08-23T00:00:00', '2016-09-13T00:00:00',
#        '2019-11-18T00:00:00', '2016-09-14T00:00:00',
#        '2019-07-18T00:00:00', '2016-10-20T00:00:00',
#        '2018-01-04T00:00:00', '2015-12-10T00:00:00',
#        '2019-02-20T00:00:00', '2019-04-03T00:00:00',
#        '2018-09-26T00:00:00', '2019-09-04T00:00:00',
#        '2019-10-29T00:00:00', '2018-09-25T00:00:00',
#        '2018-05-30T00:00:00', '2017-12-11T00:00:00',
#        '2017-12-06T00:00:00', '2019-09-26T00:00:00',
#        '2019-10-28T00:00:00', '2016-08-18T00:00:00',
#        '2016-05-09T00:00:00', '2018-06-07T00:00:00',
#        '2019-03-19T00:00:00', '2017-08-30T00:00:00',
#        '2019-05-20T00:00:00', '2018-07-10T00:00:00',
#        '2019-01-14T00:00:00', '2019-03-11T00:00:00',
#        '2019-03-13T00:00:00', '2017-07-31T00:00:00',
#        '2015-10-13T00:00:00', '2015-08-18T00:00:00',
#        '2015-02-25T00:00:00', '2019-12-05T00:00:00',
#        '2017-02-23T00:00:00', '2015-02-23T00:00:00',
#        '2015-03-18T00:00:00', '2017-05-03T00:00:00',
#        '2018-03-01T00:00:00', '2019-04-15T00:00:00',
#        '2017-12-04T00:00:00', '2015-08-12T00:00:00',
#        '2015-02-12T00:00:00', '2019-04-16T00:00:00',
#        '2015-01-14T00:00:00', '2019-09-11T00:00:00',
#        '2019-07-23T00:00:00', '2018-02-13T00:00:00',
#        '2018-01-30T00:00:00', '2019-01-31T00:00:00',
#        '2018-02-05T00:00:00', '2015-06-30T00:00:00',
#        '2016-02-16T00:00:00', '2016-04-20T00:00:00',
#        '2018-11-26T00:00:00', '2016-05-10T00:00:00',
#        '2019-11-06T00:00:00', '2015-01-05T00:00:00',
#        '2018-03-07T00:00:00', '2016-10-19T00:00:00',
#        '2018-06-20T00:00:00', '2018-02-26T00:00:00',
#        '2018-05-23T00:00:00', '2018-01-28T00:00:00',
#        '2018-01-22T00:00:00', '2018-01-27T00:00:00',
#        '2015-10-12T00:00:00', '2016-08-29T00:00:00',
#        '2015-10-29T00:00:00', '2018-05-21T00:00:00',
#        '2018-02-01T00:00:00', '2017-08-01T00:00:00',
#        '2017-12-05T00:00:00', '2016-04-13T00:00:00',
#        '2019-05-14T00:00:00', '2019-12-04T00:00:00',
#        '2019-09-23T00:00:00', '2019-06-12T00:00:00',
#        '2019-10-16T00:00:00', '2019-12-02T00:00:00',
#        '2019-04-08T00:00:00', '2016-07-20T00:00:00',
#        '2018-09-10T00:00:00', '2018-08-06T00:00:00',
#        '2018-09-13T00:00:00', '2018-10-08T00:00:00',
#        '2015-02-09T00:00:00', '2015-01-28T00:00:00',
#        '2015-01-26T00:00:00', '2015-01-29T00:00:00',
#        '2015-01-20T00:00:00', '2015-02-03T00:00:00',
#        '2018-09-27T00:00:00', '2015-09-24T00:00:00',
#        '2015-10-06T00:00:00', '2015-10-22T00:00:00',
#        '2019-08-05T00:00:00', '2019-07-30T00:00:00',
#        '2018-03-05T00:00:00', '2018-12-04T00:00:00',
#        '2019-12-18T00:00:00', '2019-01-16T00:00:00',
#        '2018-03-14T00:00:00', '2018-03-04T00:00:00',
#        '2016-09-27T00:00:00', '2016-09-28T00:00:00',
#        '2019-10-30T00:00:00', '2019-11-04T00:00:00',
#        '2018-11-01T00:00:00', '2018-09-11T00:00:00',
#        '2017-01-04T00:00:00', '2017-01-03T00:00:00',
#        '2019-06-25T00:00:00', '2019-03-04T00:00:00',
#        '2019-04-02T00:00:00', '2018-07-16T00:00:00',
#        '2015-03-17T00:00:00', '2020-01-29T00:00:00',
#        '2020-01-27T00:00:00', '2020-01-07T00:00:00',
#        '2019-12-16T00:00:00', '2019-03-18T00:00:00',
#        '2016-07-14T00:00:00', '2017-03-14T00:00:00',
#        '2017-02-07T00:00:00', '2017-02-06T00:00:00',
#        '2017-03-08T00:00:00', '2016-02-01T00:00:00',
#        '2016-01-21T00:00:00', '2017-02-09T00:00:00',
#        '2019-10-21T00:00:00', '2019-10-23T00:00:00',
#        '2015-10-14T00:00:00', '2017-10-16T00:00:00',
#        '2017-09-28T00:00:00', '2018-10-03T00:00:00',
#        '2018-08-08T00:00:00', '2015-11-23T00:00:00',
#        '2019-04-01T00:00:00', '2019-11-14T00:00:00',
#        '2018-07-24T00:00:00', '2019-11-21T00:00:00',
#        '2018-04-16T00:00:00', '2018-10-10T00:00:00',
#        '2015-11-18T00:00:00', '2019-10-10T00:00:00',
#        '2016-12-12T00:00:00', '2017-01-30T00:00:00',
#        '2018-02-12T00:00:00', '2018-07-25T00:00:00',
#        '2016-11-30T00:00:00', '2018-11-06T00:00:00',
#        '2016-02-10T00:00:00', '2015-05-28T00:00:00',
#        '2015-10-28T00:00:00', '2017-11-30T00:00:00',
#        '2015-10-01T00:00:00', '2016-06-23T00:00:00',
#        '2016-06-21T00:00:00', '2017-12-07T00:00:00',
#        '2015-09-30T00:00:00', '2015-10-15T00:00:00',
#        '2017-04-10T00:00:00', '2015-01-15T00:00:00',
#        '2017-04-13T00:00:00', '2018-05-29T00:00:00',
#        '2017-03-07T00:00:00', '2017-12-12T00:00:00',
#        '2019-04-09T00:00:00', '2016-09-12T00:00:00',
#        '2015-09-29T00:00:00', '2016-10-17T00:00:00',
#        '2016-01-19T00:00:00', '2019-01-09T00:00:00',
#        '2019-03-12T00:00:00', '2016-07-11T00:00:00',
#        '2019-09-30T00:00:00', '2015-10-24T00:00:00',
#        '2018-07-23T00:00:00', '2016-08-01T00:00:00',
#        '2018-04-02T00:00:00', '2019-10-15T00:00:00',
#        '2019-10-24T00:00:00', '2015-03-03T00:00:00',
#        '2018-08-09T00:00:00', '2018-06-28T00:00:00',
#        '2015-11-17T00:00:00', '2018-01-23T00:00:00',
#        '2018-01-24T00:00:00', '2017-11-28T00:00:00',
#        '2018-06-27T00:00:00', '2017-06-12T00:00:00',
#        '2020-01-09T00:00:00', '2020-01-21T00:00:00',
#        '2020-01-08T00:00:00', '2016-08-17T00:00:00',
#        '2019-04-22T00:00:00', '2017-03-04T00:00:00',
#        '2017-03-05T00:00:00', '2017-03-06T00:00:00',
#        '2016-03-02T00:00:00', '2017-11-02T00:00:00',
#        '2016-12-21T00:00:00', '2016-12-22T00:00:00',
#        '2017-07-29T00:00:00', '2017-07-30T00:00:00',
#        '2017-03-28T00:00:00', '2017-07-27T00:00:00',
#        '2017-07-28T00:00:00', '2017-03-25T00:00:00',
#        '2017-03-26T00:00:00', '2017-03-27T00:00:00',
#        '2016-12-27T00:00:00', '2016-12-28T00:00:00',
#        '2017-03-24T00:00:00', '2016-12-23T00:00:00',
#        '2016-12-24T00:00:00', '2016-12-26T00:00:00',
#        '2017-07-26T00:00:00', '2017-07-25T00:00:00',
#        '2017-10-24T00:00:00', '2018-10-23T00:00:00',
#        '2018-11-05T00:00:00', '2016-10-25T00:00:00',
#        '2019-08-07T00:00:00', '2019-05-30T00:00:00',
#        '2018-04-30T00:00:00', '2015-03-10T00:00:00',
#        '2017-01-05T00:00:00', '2017-01-23T00:00:00',
#        '2017-01-26T00:00:00', '2017-02-21T00:00:00',
#        '2017-02-22T00:00:00', '2018-09-05T00:00:00',
#        '2018-10-18T00:00:00', '2017-09-14T00:00:00',
#        '2016-06-14T00:00:00', '2017-09-12T00:00:00',
#        '2019-04-23T00:00:00', '2017-11-13T00:00:00',
#        '2017-06-14T00:00:00', '2017-11-14T00:00:00',
#        '2018-11-28T00:00:00', '2017-05-15T00:00:00',
#        '2017-03-22T00:00:00', '2018-04-03T00:00:00',
#        '2018-03-19T00:00:00', '2018-04-10T00:00:00',
#        '2015-10-05T00:00:00', '2015-04-02T00:00:00',
#        '2015-09-15T00:00:00', '2017-05-18T00:00:00',
#        '2019-07-10T00:00:00', '2017-05-17T00:00:00',
#        '2015-07-06T00:00:00', '2019-08-13T00:00:00',
#        '2016-09-07T00:00:00', '2018-01-16T00:00:00',
#        '2018-01-29T00:00:00', '2015-09-02T00:00:00',
#        '2018-12-12T00:00:00', '2016-06-13T00:00:00',
#        '2016-05-24T00:00:00', '2017-05-24T00:00:00',
#        '2018-05-01T00:00:00', '2017-07-10T00:00:00',
#        '2016-11-29T00:00:00', '2015-09-17T00:00:00',
#        '2017-08-02T00:00:00', '2016-07-18T00:00:00',
#        '2018-01-10T00:00:00', '2016-02-02T00:00:00',
#        '2015-09-03T00:00:00', '2016-06-06T00:00:00',
#        '2016-05-17T00:00:00', '2016-06-15T00:00:00',
#        '2015-10-08T00:00:00', '2017-10-10T00:00:00',
#        '2019-05-02T00:00:00', '2017-06-01T00:00:00',
#        '2019-09-24T00:00:00', '2016-11-28T00:00:00',
#        '2017-03-15T00:00:00', '2017-09-26T00:00:00',
#        '2017-06-06T00:00:00', '2016-06-02T00:00:00',
#        '2016-04-06T00:00:00', '2016-03-15T00:00:00',
#        '2015-08-03T00:00:00', '2017-09-11T00:00:00',
#        '2017-09-27T00:00:00', '2019-01-10T00:00:00',
#        '2017-10-26T00:00:00', '2019-05-01T00:00:00',
#        '2018-04-05T00:00:00', '2018-05-03T00:00:00',
#        '2017-10-02T00:00:00', '2018-03-08T00:00:00',
#        '2019-02-12T00:00:00', '2015-12-12T00:00:00',
#        '2019-10-09T00:00:00', '2017-05-04T00:00:00',
#        '2016-06-25T00:00:00', '2019-02-13T00:00:00',
#        '2019-05-09T00:00:00', '2016-05-25T00:00:00',
#        '2016-01-02T00:00:00', '2015-09-11T00:00:00',
#        '2015-09-13T00:00:00', '2015-09-12T00:00:00',
#        '2017-10-09T00:00:00', '2018-04-04T00:00:00',
#        '2015-09-21T00:00:00', '2016-05-23T00:00:00',
#        '2016-05-18T00:00:00', '2019-05-22T00:00:00',
#        '2015-03-11T00:00:00', '2015-03-30T00:00:00',
#        '2015-08-17T00:00:00', '2016-08-09T00:00:00',
#        '2017-09-07T00:00:00', '2016-04-28T00:00:00',
#        '2016-04-26T00:00:00', '2019-12-12T00:00:00',
#        '2017-11-29T00:00:00', '2019-01-07T00:00:00',
#        '2017-05-08T00:00:00', '2017-04-12T00:00:00',
#        '2018-01-31T00:00:00', '2019-10-14T00:00:00',
#        '2015-01-27T00:00:00', '2018-10-24T00:00:00',
#        '2017-03-20T00:00:00', '2016-04-07T00:00:00',
#        '2015-03-04T00:00:00', '2019-06-04T00:00:00',
#        '2015-04-22T00:00:00', '2018-01-25T00:00:00',
#        '2018-03-21T00:00:00', '2018-01-18T00:00:00',
#        '2017-05-02T00:00:00', '2018-05-09T00:00:00',
#        '2019-11-13T00:00:00', '2019-11-05T00:00:00',
#        '2018-04-18T00:00:00', '2019-10-17T00:00:00',
#        '2017-05-09T00:00:00', '2017-05-16T00:00:00',
#        '2017-05-10T00:00:00', '2019-04-24T00:00:00',
#        '2018-10-11T00:00:00', '2019-01-08T00:00:00',
#        '2018-08-21T00:00:00', '2018-09-18T00:00:00',
#        '2017-05-22T00:00:00', '2018-09-20T00:00:00',
#        '2015-02-17T00:00:00', '2016-06-07T00:00:00',
#        '2019-08-01T00:00:00', '2017-09-13T00:00:00',
#        '2017-02-08T00:00:00', '2017-02-13T00:00:00',
#        '2018-05-22T00:00:00', '2016-11-16T00:00:00',
#        '2017-11-27T00:00:00', '2019-10-22T00:00:00',
#        '2018-03-20T00:00:00', '2017-10-12T00:00:00',
#        '2017-10-11T00:00:00', '2017-10-17T00:00:00',
#        '2016-03-14T00:00:00', '2015-10-20T00:00:00',
#        '2016-11-02T00:00:00', '2015-07-27T00:00:00',
#        '2015-09-08T00:00:00', '2018-05-10T00:00:00',
#        '2017-11-20T00:00:00', '2015-02-26T00:00:00',
#        '2019-06-13T00:00:00', '2015-07-16T00:00:00',
#        '2015-07-13T00:00:00', '2019-09-12T00:00:00',
#        '2019-07-31T00:00:00', '2015-07-22T00:00:00',
#        '2019-09-09T00:00:00', '2019-08-22T00:00:00',
#        '2015-07-15T00:00:00', '2017-08-29T00:00:00',
#        '2018-04-23T00:00:00', '2018-09-04T00:00:00',
#        '2017-07-12T00:00:00', '2019-07-29T00:00:00',
#        '2019-07-22T00:00:00', '2019-12-10T00:00:00',
#        '2018-01-09T00:00:00', '2017-03-16T00:00:00',
#        '2016-08-02T00:00:00', '2019-05-07T00:00:00',
#        '2017-08-08T00:00:00', '2016-12-01T00:00:00',
#        '2016-06-27T00:00:00', '2017-09-18T00:00:00',
#        '2019-01-29T00:00:00', '2019-02-21T00:00:00',
#        '2016-10-06T00:00:00', '2019-03-21T00:00:00',
#        '2015-06-29T00:00:00', '2019-06-06T00:00:00',
#        '2017-02-27T00:00:00', '2019-09-10T00:00:00',
#        '2019-06-10T00:00:00', '2015-09-10T00:00:00',
#        '2015-07-28T00:00:00', '2017-01-25T00:00:00',
#        '2018-12-05T00:00:00', '2019-04-04T00:00:00',
#        '2019-07-15T00:00:00', '2017-03-21T00:00:00',
#        '2017-04-04T00:00:00', '2015-02-04T00:00:00',
#        '2019-05-16T00:00:00', '2016-08-24T00:00:00',
#        '2015-01-21T00:00:00', '2019-05-28T00:00:00',
#        '2018-06-19T00:00:00', '2018-07-26T00:00:00',
#        '2018-08-01T00:00:00', '2017-10-25T00:00:00',
#        '2017-06-05T00:00:00', '2015-07-21T00:00:00',
#        '2016-11-17T00:00:00', '2015-08-25T00:00:00',
#        '2015-08-13T00:00:00', '2017-11-16T00:00:00',
#        '2017-11-06T00:00:00', '2016-01-12T00:00:00',
#        '2015-03-19T00:00:00', '2017-08-07T00:00:00',
#        '2015-07-20T00:00:00', '2019-05-15T00:00:00',
#        '2016-08-16T00:00:00', '2019-12-11T00:00:00',
#        '2015-12-01T00:00:00', '2018-06-11T00:00:00',
#        '2019-04-11T00:00:00', '2017-03-01T00:00:00',
#        '2018-05-16T00:00:00', '2018-04-25T00:00:00',
#        '2016-05-31T00:00:00', '2019-03-20T00:00:00',
#        '2015-07-18T00:00:00', '2015-07-19T00:00:00',
#        '2015-07-23T00:00:00', '2015-07-25T00:00:00',
#        '2015-07-26T00:00:00', '2019-06-24T00:00:00',
#        '2018-05-02T00:00:00', '2015-07-17T00:00:00',
#        '2016-11-03T00:00:00', '2016-08-22T00:00:00',
#        '2018-05-28T00:00:00', '2018-06-04T00:00:00',
#        '2017-08-24T00:00:00', '2017-09-19T00:00:00',
#        '2019-04-10T00:00:00', '2020-01-23T00:00:00',
#        '2015-07-24T00:00:00', '2016-09-20T00:00:00',
#        '2019-02-14T00:00:00', '2017-08-23T00:00:00',
#        '2016-07-06T00:00:00', '2017-04-06T00:00:00',
#        '2018-08-20T00:00:00', '2018-07-11T00:00:00',
#        '2019-08-27T00:00:00', '2015-10-25T00:00:00',
#        '2016-07-24T00:00:00', '2016-07-21T00:00:00',
#        '2016-07-23T00:00:00', '2016-11-01T00:00:00',
#        '2015-11-09T00:00:00', '2017-07-13T00:00:00',
#        '2018-03-06T00:00:00', '2018-06-13T00:00:00',
#        '2018-03-02T00:00:00', '2017-03-02T00:00:00',
#        '2015-12-03T00:00:00', '2019-01-15T00:00:00',
#        '2019-01-17T00:00:00', '2019-01-28T00:00:00',
#        '2018-10-29T00:00:00', '2017-06-08T00:00:00',
#        '2016-02-08T00:00:00', '2019-01-24T00:00:00',
#        '2018-11-07T00:00:00', '2015-03-31T00:00:00',
#        '2016-08-31T00:00:00', '2015-05-20T00:00:00',
#        '2015-05-26T00:00:00', '2018-06-06T00:00:00',
#        '2018-05-14T00:00:00', '2018-09-06T00:00:00',
#        '2017-09-20T00:00:00', '2018-10-17T00:00:00',
#        '2017-04-18T00:00:00', '2019-12-03T00:00:00',
#        '2020-01-22T00:00:00', '2016-08-03T00:00:00',
#        '2019-09-18T00:00:00', '2018-08-07T00:00:00',
#        '2017-10-23T00:00:00', '2015-05-11T00:00:00',
#        '2015-05-27T00:00:00', '2018-10-30T00:00:00',
#        '2016-09-26T00:00:00', '2016-04-21T00:00:00',
#        '2015-06-22T00:00:00', '2015-08-10T00:00:00',
#        '2016-06-29T00:00:00', '2018-03-12T00:00:00',
#        '2018-01-11T00:00:00', '2016-04-04T00:00:00',
#        '2016-05-02T00:00:00', '2018-08-13T00:00:00',
#        '2017-08-22T00:00:00', '2018-12-13T00:00:00',
#        '2019-12-17T00:00:00', '2017-07-11T00:00:00',
#        '2015-01-07T00:00:00', '2019-09-17T00:00:00',
#        '2017-08-15T00:00:00', '2018-05-15T00:00:00',
#        '2019-03-14T00:00:00', '2017-01-24T00:00:00',
#        '2018-10-22T00:00:00', '2017-03-23T00:00:00',
#        '2018-11-14T00:00:00', '2018-11-15T00:00:00',
#        '2018-10-16T00:00:00', '2016-03-07T00:00:00',
#        '2019-07-17T00:00:00', '2019-07-16T00:00:00',
#        '2015-01-13T00:00:00', '2019-08-14T00:00:00',
#        '2017-11-15T00:00:00', '2017-11-08T00:00:00'], dtype=object)

# %%
transit_fvolumn_count_gpdf.columns
# Out:
# Index(['OBJECTID', 'CountID', 'ChannelID', 'LocationDesc', 'Bound',
#        'StartDate', 'StartDay', 'StartTime', 'EndDate', 'EndDay', 'EndTime',
#        'ADTVolume', 'AMVolume', 'AMPkHrVol', 'AMPkHrTime', 'AMPkHrFactor',
#        'PMVolume', 'PMPkHrVol', 'PMPkHrTime', 'PMPkHrFactor', 'ExceptType',
#        'NumChannels', 'ChannelNum', 'Conditions', 'Comment', 'Duration',
#        'IntervalLen', 'DeviceRef', 'LocationID', 'LocationClass',
#        'CountLocDesc', 'CountType', 'geometry'],
#       dtype='object')

# %%
len(transit_volumn_count_gpdf)
# Out:
# 6877

# %%
business_districts_gpdf.head()
# Out:
#    OBJECTID           BLDG_ID        STATE_ID  BLDG_NUMB BLDG_STAT  \
# 0         1   1N2E36AD-600-B2   1N2E36AD  600        2.0  Existing
# 1         2  1N1E28DD-1700-B1  1N1E28DD  1700        1.0  Existing
# 2         3  1N1E28DC-1000-B1  1N1E28DC  1000        1.0  Existing
# 3         4  1N1E28DC-1300-B1  1N1E28DC  1300        1.0  Existing
# 4         5  1N1E26CC-8100-B1  1N1E26CC  8100        1.0  Existing
#
#                 BLDG_NAME               BLDG_ADDR BLDG_TYPE  \
# 0    893-895 NE 162ND AVE    893-895 NE 162ND AVE      None
# 1   1701-1705 NW 14TH AVE   1701-1705 NW 14TH AVE      None
# 2       1627 NW SAVIER ST       1627 NW SAVIER ST      None
# 3        1715 NW 17TH AVE        1715 NW 17TH AVE      None
# 4  801-805 NE BROADWAY ST  801-805 NE BROADWAY ST      None
#
#                     BLDG_USE  BLDG_SQFT  ...    LAT_CTR    LONG_CTR   PROPKEY  \
# 0  Single Family Residential      406.0  ...  45.529583 -122.497241  676969.0
# 1                 Industrial     7275.0  ...  45.535205 -122.685863  713361.0
# 2          Commercial Retail     4085.0  ...  45.535221 -122.688445  861743.0
# 3                 Industrial    39576.0  ...  45.535183 -122.689147  847700.0
# 4                    Parking      435.0  ...  45.535390 -122.657430  665848.0
#
#    EDIT_STAT DATA_SOURCE  Shape_Length   Shape_Area RETIRED_BY  RETIRED_DATE  \
# 0       None         PDX     35.045386    76.731539       None          None
# 1       None         PDX    160.389672  1095.292343       None          None
# 2       None         PDX    114.132522   773.467267       None          None
# 3       None         PDX    249.485517  3493.822814       None          None
# 4       None         PDX     36.320815    82.415959       None          None
#
#                                             geometry
# 0  POLYGON ((-122.49722 45.52960, -122.49721 45.5...
# 1  POLYGON ((-122.68575 45.53524, -122.68576 45.5...
# 2  POLYGON ((-122.68836 45.53534, -122.68856 45.5...
# 3  POLYGON ((-122.68878 45.53532, -122.68956 45.5...
# 4  POLYGON ((-122.65740 45.53543, -122.65748 45.5...
#
# [5 rows x 55 columns]

# %%
len(business_districts_gpdf)
# Out:
# 250141

# %%
business_districts_gpdf.columns
# Out:
# Index(['OBJECTID', 'BLDG_ID', 'STATE_ID', 'BLDG_NUMB', 'BLDG_STAT',
#        'BLDG_NAME', 'BLDG_ADDR', 'BLDG_TYPE', 'BLDG_USE', 'BLDG_SQFT',
#        'SQFT_SRC', 'NUM_STORY', 'STORY_SRC', 'UNITS_RES', 'UNITS_SRC',
#        'OCCUP_CAP', 'OCCUP_SRC', 'ADA_ACCESS', 'YEAR_BUILT', 'STRUC_TYPE',
#        'STRUC_COND', 'SOURCE', 'SOURCE_REF', 'AVG_HEIGHT', 'MAX_HEIGHT',
#        'MIN_HEIGHT', 'HEIGHT_SRC', 'SURF_ELEV', 'SURF_OFF', 'SURF_ADJ',
#        'SURF_SRC', 'ROOF_ELEV', 'ROOF_TYPE', 'ORIENT', 'VOLUME', 'CREATED_BY',
#        'CREATEDATE', 'MOD_NAME', 'MOD_DATE', 'FIELD_DATE', 'REVIEW', 'NOTES',
#        'SUBAREA', 'WSUNIQUEID', 'BPS_BLDGID', 'LAT_CTR', 'LONG_CTR', 'PROPKEY',
#        'EDIT_STAT', 'DATA_SOURCE', 'Shape_Length', 'Shape_Area', 'RETIRED_BY',
#        'RETIRED_DATE', 'geometry'],
#       dtype='object')

# %%
business_districts_gpdf.YEAR_BUILT
# Out:
# 0         1992.0
# 1         1947.0
# 2         1964.0
# 3         1971.0
# 4         1900.0
# 5         1889.0
# 6         1889.0
# 7         1952.0
# 8         2007.0
# 9         2007.0
# 10        2007.0
# 11           NaN
# 12        1915.0
# 13        1906.0
# 14        2001.0
# 15        1927.0
# 16        1921.0
# 17        1969.0
# 18        1896.0
# 19        1989.0
# 20        1896.0
# 21        1989.0
# 22        1908.0
# 23        1968.0
# 24        1973.0
# 25        1979.0
# 26        1973.0
# 27        1963.0
# 28        2007.0
# 29        1912.0
#            ...
# 250111       NaN
# 250112       NaN
# 250113       NaN
# 250114       NaN
# 250115       NaN
# 250116       NaN
# 250117       NaN
# 250118       NaN
# 250119       NaN
# 250120       NaN
# 250121       NaN
# 250122       NaN
# 250123    2019.0
# 250124    1937.0
# 250125    1937.0
# 250126    2019.0
# 250127    1937.0
# 250128    2019.0
# 250129    1937.0
# 250130    1937.0
# 250131    2019.0
# 250132    1940.0
# 250133       NaN
# 250134       NaN
# 250135       NaN
# 250136       NaN
# 250137       NaN
# 250138       NaN
# 250139       NaN
# 250140       NaN
# Name: YEAR_BUILT, Length: 250141, dtype: float64
