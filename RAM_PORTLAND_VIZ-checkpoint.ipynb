# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import geopandas as gpd
from shapely import wkt

# %%
data_shapes = pd.read_csv("~/Downloads/Final_merged_city_portland.csv")

# %%
data_shapes.head()
# Out:
#    Unnamed: 0       geo_id                                      centroid  \
# 0        2432  41051010402  POINT (-122.3356996936241 45.48566422279789)
# 1        2435  41051010402  POINT (-122.3356996936241 45.48566422279789)
# 2        2438  41051010402  POINT (-122.3356996936241 45.48566422279789)
# 3        2441  41051010402  POINT (-122.3356996936241 45.48566422279789)
# 4        2444  41051010402   POINT (-122.335683996136 45.48565935229686)
#
#    year                                           geometry  total_tran  \
# 0  2010  MULTIPOLYGON (((-122.3868792758254 45.51902980...      2601.0
# 1  2011  MULTIPOLYGON (((-122.3868792758254 45.51902980...      2826.0
# 2  2012  MULTIPOLYGON (((-122.3868792758254 45.51902980...      2868.0
# 3  2013  MULTIPOLYGON (((-122.3868792758254 45.51902980...      2876.0
# 4  2014  MULTIPOLYGON (((-122.3868792758254 45.51902980...      3078.0
#
#       pop    edut  collegemale  collegefemale  ...  Empratio  estabratio  \
# ...

# %%
data_2010 = data_shapes.loc[data_shapes['year'] == 2010]
data_2011 = data_shapes.loc[data_shapes['year'] == 2011]
data_2012 = data_shapes.loc[data_shapes['year'] == 2012]
data_2013 = data_shapes.loc[data_shapes['year'] == 2013]
data_2014 = data_shapes.loc[data_shapes['year'] == 2014]
data_2015 = data_shapes.loc[data_shapes['year'] == 2015]
data_2016 = data_shapes.loc[data_shapes['year'] == 2016]
data_2017 = data_shapes.loc[data_shapes['year'] == 2017]

# %%
data_list = ['data_2010','data_2011','data_2012','data_2013','data_2014','data_2015','data_2016','data_2017']

# %%
data_2010['geometry'] = data_2010['geometry'].apply(wkt.loads)
data_2010['centroid'] = data_2010['centroid'].apply(wkt.loads)
data_2010 = gpd.GeoDataFrame(data_2010, geometry='geometry')

###############

data_2011['geometry'] = data_2011['geometry'].apply(wkt.loads)
data_2011['centroid'] = data_2011['centroid'].apply(wkt.loads)
data_2011 = gpd.GeoDataFrame(data_2011, geometry='geometry')

################
# Out:
# C:\Users\Ram\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Ram\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Ram\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_2010.head()
# Out:
#     Unnamed: 0       geo_id                                      centroid  \
# 0         2432  41051010402  POINT (-122.3356996936241 45.48566422279789)
# 8         2536  41051010500    POINT (-122.08527042624 45.52768157713402)
# 16        2537  41051010500    POINT (-122.08527042624 45.52768157713402)
# 24        2088  41051009603  POINT (-122.4608485441421 45.52931048858725)
# 32        2328  41051010100   POINT (-122.444171605879 45.52613866368701)
#
#     year                                           geometry  total_tran  \
# 0   2010  MULTIPOLYGON (((-122.38688 45.51903, -122.3726...      2601.0
# 8   2010  MULTIPOLYGON (((-122.39710 45.57260, -122.3918...      1765.0
# 16  2010  MULTIPOLYGON (((-122.39710 45.57260, -122.3918...      1765.0
# 24  2010  MULTIPOLYGON (((-122.46613 45.53953, -122.4656...      1619.0
# 32  2010  MULTIPOLYGON (((-122.45665 45.53949, -122.4533...      3791.0
#
#        pop    edut  collegemale  collegefemale  ...     Empratio  estabratio  \
# ...

# %%
import cartoframes
from cartoframes.auth import set_default_credentials
from cartoframes.viz import Map, Layer, popup_element, size_bins_style

# %%
# from cartoframes.viz.helpers import color_bins_layer

from cartoframes.viz import Map, Layer, basemaps, popup_element, basic_style, color_category_style, color_bins_style, default_legend, color_bins_legend, category_widget, formula_widget,  histogram_widget

# %%
set_default_credentials('https://cartoframes.carto.com')

# %%
gdf_2010 = gpd.GeoDataFrame(data_2010, geometry='geometry', crs={'init': 'epsg:4326'})
gdf_2011 = gpd.GeoDataFrame(data_2011, geometry='geometry', crs={'init': 'epsg:4326'})
# gdf_2012 = gpd.GeoDataFrame(data_2012, geometry='geometry', crs={'init': 'epsg:4326'})
# gdf_2013 = gpd.GeoDataFrame(data_2013, geometry='geometry', crs={'init': 'epsg:4326'})
# gdf_2014 = gpd.GeoDataFrame(data_2014, geometry='geometry', crs={'init': 'epsg:4326'})
# gdf_2015 = gpd.GeoDataFrame(data_2015, geometry='geometry', crs={'init': 'epsg:4326'})
# gdf_2016 = gpd.GeoDataFrame(data_2016, geometry='geometry', crs={'init': 'epsg:4326'})
# gdf_2017 = gpd.GeoDataFrame(data_2017, geometry='geometry', crs={'init': 'epsg:4326'})
# Out:
# C:\Users\Ram\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
Map(Layer(gdf_2010,color_bins_style('Empratio'),popup_hover=[popup_element('pop','Population')]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
Map(Layer(gdf_2011,color_bins_style('Empratio'),popup_hover=[popup_element('pop','Population')]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...
